# %% [markdown]
# This file creates a gene regulatory network (GRN) with gene expression data.
#
# 1. Import all necessary packages.

# %%
import pandas as pd
import os
import seaborn as sns
import scipy
import matplotlib.pyplot as plt
import glob
import numpy as np
import grn_finder
import structs
import importlib
# Out:
# <module 'structs' from '/Users/jingliu/Documents/haase/haase_lab/structs.py'>

# %%
importlib.reload(grn_finder)
importlib.reload(structs)
# Out:
# <module 'structs' from '/Users/jingliu/Documents/haase/haase_lab/structs.py'>

# %% [markdown]
# 2. extract data from file

# %%
df = grn_finder.extract_expression_data("/Users/jingliu/Documents/haase/IDEA_data/idea_tall_expression_data.tsv", sep='\t')
# Out:
# Reading file
# File read successfully

# %% [markdown]
# If you want to use data from one particular strand, run the following code chunk:

# %%
strain = "" # enter the name of strain
df = df[df['strain'] == strain]

# %%
# Out:
# <class 'pandas.core.series.Series'>
