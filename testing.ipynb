# %%
import pandas as pd
import os
import seaborn as sns
import scipy
import matplotlib.pyplot as plt
import glob
import numpy as np
import grn_finder as grn
import importlib

# %%
importlib.reload(grn)
# Out:
# <module 'grn_finder' from '/Users/jingliu/Documents/haase/haase_lab/grn_finder.py'>

# %%
dir = "/Users/jingliu/Documents/haase/IDEA_data"
file = "idea_tall_expression_data.tsv"
path = os.path.join(dir, file)

gene_dir = '/Users/jingliu/Documents/haase/haase_lab'
gene_file = 'genes_sorted.csv'
gene_path = os.path.join(gene_dir, gene_file)

df = grn.filter_df(path, gene_path)

# %%
grn.create_heat_maps(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 grn.create_heat_maps(df)
#
# File ~/Documents/haase/haase_lab/grn_finder.py:149, in create_heat_maps(df)
#     146 heatmap_data = tf_data.pivot(index='GeneName', columns='time', values='log2_cleaned_ratio')
#     148 # Make subplot
# --> 149 plt.subplot(2, 4, i + 1)
#     150 sns.heatmap(heatmap_data, cmap=haase, cbar=True)
#     151 plt.title(tf)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/pyplot.py:1529, in subplot(*args, **kwargs)
#    1526 fig = gcf()
#    1528 # First, search for an existing subplot with a matching spec.
# -> 1529 key = SubplotSpec._from_subplot_args(fig, args)
#    1531 for ax in fig.axes:
#    1532     # If we found an Axes at the position, we can reuse it if the user passed no
#    1533     # kwargs or if the Axes class and kwargs are identical.
#    1534     if (ax.get_subplotspec() == key
#    1535         and (kwargs == {}
#    1536              or (ax._projection_init
#    1537                  == fig._process_projection_requirements(**kwargs)))):
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/gridspec.py:589, in SubplotSpec._from_subplot_args(figure, args)
#     587 else:
#     588     if not isinstance(num, Integral) or num < 1 or num > rows*cols:
# --> 589         raise ValueError(
#     590             f"num must be an integer with 1 <= num <= {rows*cols}, "
#     591             f"not {num!r}"
#     592         )
#     593     i = j = num
#     594 return gs[i-1:j]
#
# ValueError: num must be an integer with 1 <= num <= 8, not 9
