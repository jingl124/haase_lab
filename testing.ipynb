# %%
import pandas as pd
import os
import seaborn as sns
import scipy
import matplotlib.pyplot as plt
import numpy as np
import structs
import importlib
import graphviz
import matplotlib
import math
import datetime
import grn_finder as grn
import grn_search as search

# %%
importlib.reload(grn)
importlib.reload(search)
# Out:
# <module 'grn_search' from '/Users/jingliu/Documents/haase/haase_lab/grn_search.py'>

# %%
df = grn.main()

# %%
file = "/Users/jingliu/Documents/haase/haase_lab/paths/paths_2024-07-25 13:23:39.csv"
search.search_paths(file, "ACE2", None)
# Out:
# Paths found:
#     Unnamed: 0 start    end                              path graph sign  \
# 0            0  ACE2   ACE2                  ['ACE2', 'ACE2']   grn  act
# 1            1  ACE2  CDC20         ['ACE2', 'SWI5', 'CDC20']   grn  act
# 2            2  ACE2   CLB1          ['ACE2', 'SWI5', 'CLB1']   grn  act
# 3            3  ACE2   CLB5          ['ACE2', 'SWI5', 'CLB5']   grn  rep
# 4            4  ACE2   CLB6                  ['ACE2', 'CLB6']   grn  rep
# 5            5  ACE2   CLN3                  ['ACE2', 'CLN3']   ref  act
# 6            6  ACE2   MBP1  ['ACE2', 'CLN3', 'STB1', 'MBP1']   ref  act
# 7            7  ACE2   NDD1                  ['ACE2', 'NDD1']   grn  rep
# 8            8  ACE2   NRM1                  ['ACE2', 'NRM1']   grn  rep
# 9            9  ACE2   PLM2                  ['ACE2', 'PLM2']   grn  rep
# 10          10  ACE2   STB1          ['ACE2', 'CLN3', 'STB1']   ref  rep
# 11          11  ACE2   SWI4                  ['ACE2', 'SWI4']   grn  rep
# ...

# %%
search.get_out_edges("FKH1")
# Out:
# ['CLN2', 'FKH1', 'MBP1', 'SWI5', 'ACE2', 'CLB2', 'CDC20']
# ['CLN2', 'FKH1', 'MBP1', 'SWI5', 'ACE2', 'CLB2', 'CDC20']

# %%
importlib.reload(grn)
importlib.reload(search)
grn.create_heat_maps(df)
